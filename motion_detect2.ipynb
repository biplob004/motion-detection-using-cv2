# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

# cap.set(3, 480) # set width and height (optional)
# cap.set(4, 240)

prev_frame = None
current_frame = None

frame_counter = 0 
thresh_low = 25
sensitivity = 100000


while True:
    ret, frame = cap.read()
    frame_counter+=1  # couting frame
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (21, 21), 0)  # bluring to get rid of camera noise
    
    
    cv2.imshow("frame", np.hstack((frame, cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)))) # show video (optional)
    # cv2.imshow('gray', gray)
     
    current_frame = gray 
    
    if type(prev_frame) == type(None): # checking if it is first frame
        prev_frame = current_frame 
        
    frame_diff = cv2.absdiff(prev_frame, current_frame) # getting absolute difference between two frames
    thresh = cv2.threshold(frame_diff, thresh_low, 255, cv2.THRESH_BINARY)[1] # setting a threshold, and set zero below this 
     
    motion = np.sum(thresh) # Sum intensity of pixels after these preprocessing
    
    if(motion > sensitivity): # orbitarily set value here, it will define sensitivity
        print('Motion detected with intensity: ',motion)
        # Here do all the things you want to do after detection of motion

        
    if frame_counter > 100: # reset frame counter after everry 100 frame, you can change this value
        prev_frame = current_frame
        frame_counter = 0
        
        
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cv2.waitKey(0)
cap.release()
cv2.destroyAllWindows()
# Out:
# Motion detected with intensity:  221340
# Motion detected with intensity:  362610
# Motion detected with intensity:  335325
# Motion detected with intensity:  290955
# Motion detected with intensity:  534735
# Motion detected with intensity:  705075
# Motion detected with intensity:  776985
# Motion detected with intensity:  825945
# Motion detected with intensity:  875415
# Motion detected with intensity:  908820
# Motion detected with intensity:  917235
# Motion detected with intensity:  885870
# Motion detected with intensity:  881535
# Motion detected with intensity:  880515
# Motion detected with intensity:  908310
# Motion detected with intensity:  948855
# Motion detected with intensity:  997050
# Motion detected with intensity:  1027395
# Motion detected with intensity:  1041675
# Motion detected with intensity:  1044225
# Motion detected with intensity:  1047540
# Motion detected with intensity:  1046010
# Motion detected with intensity:  1042440
# Motion detected with intensity:  1057740
# Motion detected with intensity:  1056975
# Motion detected with intensity:  1051875
# Motion detected with intensity:  1051875
# Motion detected with intensity:  1051110
# Motion detected with intensity:  1046265
# Motion detected with intensity:  1046265
# Motion detected with intensity:  1053405
# Motion detected with intensity:  1063095
# Motion detected with intensity:  1062585
# Motion detected with intensity:  1064625
# Motion detected with intensity:  1067430
# Motion detected with intensity:  1077885
# Motion detected with intensity:  1083495
# Motion detected with intensity:  1079925
# Motion detected with intensity:  1083240
# Motion detected with intensity:  1077630
# Motion detected with intensity:  1081455
# Motion detected with intensity:  1082730
# Motion detected with intensity:  1076100
# Motion detected with intensity:  1086045
# Motion detected with intensity:  1086045
# Motion detected with intensity:  1087830
# Motion detected with intensity:  1090380
# Motion detected with intensity:  1094205
# Motion detected with intensity:  1098030
# Motion detected with intensity:  1093440
# Motion detected with intensity:  1101600
# Motion detected with intensity:  1093440
# Motion detected with intensity:  1093185
# Motion detected with intensity:  1090380
# Motion detected with intensity:  1081455
# Motion detected with intensity:  1078395
# Motion detected with intensity:  1074315
# Motion detected with intensity:  1066155
# Motion detected with intensity:  1057995
# Motion detected with intensity:  1059270
# Motion detected with intensity:  1055955
# Motion detected with intensity:  1060545
# Motion detected with intensity:  1057995
# Motion detected with intensity:  1059780
# Motion detected with intensity:  1066665
# Motion detected with intensity:  1068960
# Motion detected with intensity:  1064880
# Motion detected with intensity:  1068195
# Motion detected with intensity:  1074315
# Motion detected with intensity:  1075335
# Motion detected with intensity:  1078395
# Motion detected with intensity:  1083240
# Motion detected with intensity:  1075080
# Motion detected with intensity:  1090125
# Motion detected with intensity:  1091145
# Motion detected with intensity:  1088850
# Motion detected with intensity:  1087830
# Motion detected with intensity:  1087830
# Motion detected with intensity:  1089105
# Motion detected with intensity:  1091655
# Motion detected with intensity:  1091145
# Motion detected with intensity:  1086045
# Motion detected with intensity:  1089615
# Motion detected with intensity:  1087065
# Motion detected with intensity:  1088340
# Motion detected with intensity:  1082730
# Motion detected with intensity:  1094205
# Motion detected with intensity:  1091655
# Motion detected with intensity:  1093185
# Motion detected with intensity:  1088850
# Motion detected with intensity:  1089615
# Motion detected with intensity:  1085790
# Motion detected with intensity:  1090890
# Motion detected with intensity:  1090125
# Motion detected with intensity:  1083240
# Motion detected with intensity:  1088595
# Motion detected with intensity:  1087320
# Motion detected with intensity:  743070
# Motion detected with intensity:  931260
# Motion detected with intensity:  1083495
# Motion detected with intensity:  1272450
# Motion detected with intensity:  2936325
# Motion detected with intensity:  5165790
# Motion detected with intensity:  7462575
# Motion detected with intensity:  7341705
# Motion detected with intensity:  6041205
# Motion detected with intensity:  365415
